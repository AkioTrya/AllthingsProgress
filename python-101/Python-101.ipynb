# %% [markdown]
# ## DAY 1
# def, Function, and Dataclass
# ------------------------------------
# def() is a python keyword that used to define a function or a method, it points out the start of a resueable codeblock that run when being called
#
# function a multiple use, heck it's reuseable in how many times i want?, code block that only work if it being called
#
# dataclass a class that comes with a decorator, usually used to store data (havent sure yet will update)
#
# additional note:
# decorator a function that takes another function as it argument and the the behaviour longer? without making it broken, or change the orginal funciton or codeblock

# %%
def name(Name: str) -> None:
    print(Name, "hello")

def add(x: int, y: int) -> int:
    return x + y
    
def lap_time(time: float, driver: str) -> None:
    print(time, driver)

def is_fast_lap(lap: float, threshold: float) -> bool:
    return lap < threshold

def format_lap(driver: str, time: float) -> str:
    return f"{driver} - {time}s"

# %% [markdown]
# -> are used to specify our need of the output, usually int, float, str, or all value by calling Any from a library, and adding it to the main def(..., Any)
#
# so the thinking scenario of this at least on my head are based like this, oh we need a func for say water counter, we make def water_count(metric: float, req: float) -> bool:, i add boolean because i want to know whether i drink enough water or no, so we return it as return metric => req
#
# correct me if im wrong though.

# %% [markdown]
# contextlib and contextmanager
# both are confusing atleast for now and for
